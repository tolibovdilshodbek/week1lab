# %% [markdown]
# <a href="https://colab.research.google.com/github/tolibovdilshodbek/week1lab/blob/main/problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem week 1

# %%
scores = [72, 85, 90, 68, 88]
print("Scores:", scores)


average = sum(scores) / len(scores)
print("Average score:", average)


print("Highest score:", max(scores))
print("Lowest score:", min(scores))
# Out:
# Scores: [72, 85, 90, 68, 88]
# Average score: 80.6
# Highest score: 90
# Lowest score: 68
